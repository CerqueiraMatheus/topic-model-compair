# %% [markdown]
# # Preparing environment

# %%
import os
import time
import numpy as np
import pandas as pd

# Dataset
from octis.dataset.dataset import Dataset

# Metrics
from custom.metrics.TDCI import TDCI
from octis.evaluation_metrics.coherence_metrics import Coherence
from octis.evaluation_metrics.diversity_metrics import TopicDiversity

# Topic Models
from octis.models.CTM import CTM
from octis.models.ETM import ETM
from octis.models.HDP import HDP
from octis.models.LDA import LDA
from octis.models.LSI import LSI
from octis.models.NMF import NMF
from octis.models.ProdLDA import ProdLDA
from octis.models.NeuralLDA import NeuralLDA
from custom.models.CustomTop2Vec import CustomTop2Vec
from custom.models.CustomBERTopic import CustomBERTopic
# Out:
# /home/cerqra/miniconda3/envs/tm-eval/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/cerqra/miniconda3/envs/tm-eval/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/cerqra/miniconda3/envs/tm-eval/lib/python3.11/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/cerqra/miniconda3/envs/tm-eval/lib/python3.11/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
def remove_unused():
    try:
        os.remove("_train.pkl")
        os.remove("_test.pkl")
        os.remove("_val.pkl")
    except:
        pass

# %% [markdown]
# # Datasets

# %%
# Load PL 3723/2019
dataset_pl = Dataset()
dataset_pl.load_custom_dataset_from_folder("../datasets/pl_3723_2019")

# Load PEC 471/2005
dataset_pec = Dataset()
dataset_pec.load_custom_dataset_from_folder("../datasets/pec_471_2005")

# %%
print("Size of PL 3723/2019 corpus: ", len(dataset_pl.get_corpus()))
print("Size of PL 3723/2019 vocabulary: ", len(dataset_pl.get_vocabulary()))

print("Mean document length of PL 3723/2019: ", np.mean([len(doc) for doc in dataset_pl.get_corpus()]))
print("Min and max document length of PL 3723/2019: ", np.min([len(doc) for doc in dataset_pl.get_corpus()]), np.max([len(doc) for doc in dataset_pl.get_corpus()]))
# Out:
# Size of PL 3723/2019 corpus:  705
# Size of PL 3723/2019 vocabulary:  2131
# Mean document length of PL 3723/2019:  10.44822695035461
# Min and max document length of PL 3723/2019:  1 37

# %%
print("Size of PEC 471/2005 corpus: ", len(dataset_pec.get_corpus()))
print("Size of PEC 471/2005 vocabulary: ", len(dataset_pec.get_vocabulary()))
print("Mean document length of PEC 471/2005: ", np.mean([len(doc) for doc in dataset_pec.get_corpus()]))
print("Min and max document length of PEC 471/2005: ", np.min([len(doc) for doc in dataset_pec.get_corpus()]), np.max([len(doc) for doc in dataset_pec.get_corpus()]))
# Out:
# Size of PEC 471/2005 corpus:  628
# Size of PEC 471/2005 vocabulary:  2088
# Mean document length of PEC 471/2005:  11.546178343949045
# Min and max document length of PEC 471/2005:  1 48

# %% [markdown]
# # Metrics

# %%
tc_pl_metric = Coherence(texts=dataset_pl.get_corpus())
tdci_pl_metric = TDCI(texts=dataset_pl.get_corpus())
td_pl_metric = TopicDiversity()

# %%
tc_pec_metric = Coherence(texts=dataset_pec.get_corpus())
tdci_pec_metric = TDCI(texts=dataset_pec.get_corpus())
td_pec_metric = TopicDiversity()

# %%
def get_best_df(alg_name, dataset_name, use_topics=True):
    for n_topic in [10, 20, 30, 40, 50]:
        if n_topic == 10:
            df = pd.DataFrame(pd.read_csv("../tunning/csv/" + alg_name + "-" + dataset_name + ("-" + str(n_topic) if use_topics else "") + ".csv").sort_values(
                by="Mean(model_runs)", ascending=False).head(1).reset_index(drop=True))
            
        else:
            vals = pd.DataFrame(pd.read_csv("../tunning/csv/" + alg_name + "-" + dataset_name + ("-" + str(n_topic) if use_topics else "") + ".csv").sort_values(
                by="Mean(model_runs)", ascending=False).head(1).reset_index(drop=True)).to_dict()
        
            df.loc[len(df)] = {key: value[0] for key, value in vals.items()}

    return df.sort_values(by="Mean(model_runs)", ascending=False)

# %%
def get_hyperparams(df):
    return {key: value[0] for key, value in df[df.columns[8:-2]].to_dict().items()}

# %% [markdown]
# # Visualize - PL 3723/2019

# %%
# Get CTM best hyperparameters
ctm_pl_df = get_best_df("ctm", "pl_3723_2019")
ctm_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 2  dataset_name              RF                  LCB              6
# 4  dataset_name              RF                  LCB              7
# 3  dataset_name              RF                  LCB              7
# 1  dataset_name              RF                  LCB              9
# 0  dataset_name              RF                  LCB              7
#
#           time  Median(model_runs)  Mean(model_runs)  \
# 2   575.039418            0.579217          0.575805
# 4   918.352537            0.563788          0.563020
# 3   898.508395            0.562190          0.562374
# 1  1180.754644            0.533357          0.557952
# 0    69.862385            0.539070          0.535245
#
#    Standard_Deviation(model_runs) activation   dropout inference_type  \
# 2                        0.012693       relu  0.711358       combined
# 4                        0.005896       tanh  0.802842       combined
# 3                        0.019157       tanh  0.802842       combined
# 1                        0.038796       relu  0.732236       combined
# 0                        0.011260       tanh  0.802842       combined
#
#   model_type  num_epochs  num_layers  num_neurons  num_samples  num_topics  \
# 2        LDA         367           1          200           50          30
# 4    prodLDA         119           4          300           40          50
# 3    prodLDA         119           4          300           40          40
# 1    prodLDA         338           4          200           49          20
# 0    prodLDA         119           4          300           40          10
#
#   solver  Coherence(not optimized)  Topic diversity(not optimized)
# 2    sgd                 -0.104516                          0.8400
# 4    sgd                 -0.137433                          0.7840
# 3    sgd                 -0.133267                          0.8225
# 1    sgd                 -0.232828                          0.8750
# 0    sgd                 -0.244218                          0.9500

# %%
# Get ETM best hyperparameters
etm_pl_df = get_best_df("etm", "pl_3723_2019")
etm_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              2
# 1  dataset_name              RF                  LCB              7
# 2  dataset_name              RF                  LCB              4
# 4  dataset_name              RF                  LCB              6
# 3  dataset_name              RF                  LCB              4
#
#           time  Median(model_runs)  Mean(model_runs)  \
# 0    71.796367            0.424573          0.424196
# 1  1120.583583            0.404651          0.406584
# 2   127.745090            0.398066          0.397826
# 4   204.555664            0.388241          0.388373
# 3   136.023815            0.383294          0.383902
#
#    Standard_Deviation(model_runs) activation   dropout  num_epochs  \
# 0                        0.014654       relu  0.307750         137
# 1                        0.005756   softplus  0.286217         240
# 2                        0.000982   softplus  0.900379         274
# 4                        0.000800   softplus  0.150885         351
# 3                        0.004205   softplus  0.900379         274
#
#    num_neurons  num_topics optimizer  rho  t_hidden_size  \
# 0          100          10      asgd  296            487
# 1          100          20      asgd  388            440
# 2          100          30      asgd  367            471
# 4          100          50      asgd  293            786
# 3          100          40      asgd  367            471
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 0                 -0.330412                        0.630000
# 1                 -0.348936                        0.570000
# 2                 -0.443223                        0.703333
# 4                 -0.463674                        0.698000
# 3                 -0.491854                        0.780000

# %%
# Get HDP best hyperparameters
hdp_pl_df = get_best_df("hdp", "pl_3723_2019", use_topics=False)
hdp_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              3
# 1  dataset_name              RF                  LCB              3
# 2  dataset_name              RF                  LCB              3
# 3  dataset_name              RF                  LCB              3
# 4  dataset_name              RF                  LCB              3
#
#         time  Median(model_runs)  Mean(model_runs)  \
# 0  18.402431              0.3617          0.362193
# 1  18.402431              0.3617          0.362193
# 2  18.402431              0.3617          0.362193
# 3  18.402431              0.3617          0.362193
# 4  18.402431              0.3617          0.362193
#
#    Standard_Deviation(model_runs)    kappa        tau  \
# 0                        0.001432  0.52115  72.429074
# 1                        0.001432  0.52115  72.429074
# 2                        0.001432  0.52115  72.429074
# 3                        0.001432  0.52115  72.429074
# 4                        0.001432  0.52115  72.429074
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 0                 -0.504912                           0.682
# 1                 -0.504912                           0.682
# 2                 -0.504912                           0.682
# 3                 -0.504912                           0.682
# 4                 -0.504912                           0.682

# %%
# Get LDA best hyperparameters
lda_pl_df = get_best_df("lda", "pl_3723_2019")
lda_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 1  dataset_name              RF                  LCB              1
# 2  dataset_name              RF                  LCB              0
# 0  dataset_name              RF                  LCB              6
# 4  dataset_name              RF                  LCB              5
# 3  dataset_name              RF                  LCB              0
#
#           time  Median(model_runs)  Mean(model_runs)  \
# 1   320.162946            0.648233          0.634026
# 2    79.917479            0.623739          0.624827
# 0   206.380311            0.622230          0.613843
# 4  1946.726467            0.585922          0.581863
# 3    70.710448            0.579382          0.577358
#
#    Standard_Deviation(model_runs)       alpha  chunksize     decay  \
# 1                        0.029963  asymmetric       1363  0.634605
# 2                        0.006107  asymmetric      41715  0.534526
# 0                        0.016544  asymmetric       2644  0.726734
# 4                        0.020270   symmetric      15623  0.875413
# 3                        0.006869  asymmetric      41715  0.534526
#
#    gamma_threshold  iterations  num_topics    offset  passes  \
# 1         0.458661          12          20  8.260694     383
# 2         0.320128         488          30  2.203020      84
# 0         0.252910         430          10  9.909233     224
# 4         0.054385         632          50  5.997963     428
# 3         0.320128         488          40  2.203020      84
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 1                  0.056237                           0.780
# 2                  0.050879                           0.750
# 0                 -0.022234                           0.880
# 4                 -0.023105                           0.732
# 3                  0.026591                           0.665

# %%
# Get LSI best hyperparameters
lsi_pl_df = get_best_df("lsi", "pl_3723_2019")
lsi_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              6
# 1  dataset_name              RF                  LCB              2
# 3  dataset_name              RF                  LCB              9
# 2  dataset_name              RF                  LCB              3
# 4  dataset_name              RF                  LCB              8
#
#          time  Median(model_runs)  Mean(model_runs)  \
# 0   29.471644            0.457595          0.477086
# 1   29.625747            0.410358          0.410266
# 3  233.488050            0.352640          0.352373
# 2   42.899925            0.345518          0.351764
# 4  307.471560            0.324974          0.327507
#
#    Standard_Deviation(model_runs)  chunksize     decay  extra_samples  \
# 0                        0.029005      37889  0.748736             33
# 1                        0.009478      34399  0.779017            147
# 3                        0.002678      42688  0.650908             19
# 2                        0.014632      30062  0.872725             51
# 4                        0.011942      35816  0.720960            169
#
#    num_topics  power_iters  Coherence(not optimized)  \
# 0          10            1                 -0.004537
# 1          20            6                 -0.106995
# 3          40            1                 -0.209854
# 2          30            2                 -0.147643
# 4          50            1                 -0.240044
#
#    Topic diversity(not optimized)
# 0                           0.430
# 1                           0.380
# 3                           0.320
# 2                           0.290
# 4                           0.286

# %%
# Get NeuralLDA best hyperparameters
neurallda_pl_df = get_best_df("neurallda", "pl_3723_2019")
neurallda_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 4  dataset_name              RF                  LCB              9
# 1  dataset_name              RF                  LCB              7
# 0  dataset_name              RF                  LCB              3
# 2  dataset_name              RF                  LCB              9
# 3  dataset_name              RF                  LCB              7
#
#           time  Median(model_runs)  Mean(model_runs)  \
# 4   643.911896            0.561857          0.565034
# 1   163.790888            0.494397          0.495968
# 0    71.804030            0.490811          0.492855
# 2    21.203326            0.481545          0.477085
# 3  1578.883242            0.450504          0.450578
#
#    Standard_Deviation(model_runs) activation   dropout        lr  momentum  \
# 4                        0.019965       relu  0.432510  0.008744  0.796968
# 1                        0.004017       relu  0.266380  0.009618  0.897813
# 0                        0.003417       relu  0.759705  0.004190  0.511511
# 2                        0.007745       relu  0.937184  0.009627  0.523781
# 3                        0.001467       relu  0.266380  0.009618  0.897813
#
#    num_epochs  num_layers  num_neurons  num_samples  num_topics solver  \
# 4         114           1          950           42          50   adam
# 1          74           1          580           42          20    sgd
# 0         348           4          547           49          10    sgd
# 2         287           9          461           39          30   adam
# 3          74           1          580           42          40    sgd
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 4                 -0.155814                        0.840000
# 1                 -0.304526                        0.845000
# 0                 -0.283882                        0.780000
# 2                 -0.277063                        0.686667
# 3                 -0.343345                        0.717500

# %%
# Get NMF best hyperparameters
nmf_pl_df = get_best_df("nmf", "pl_3723_2019")
nmf_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 3  dataset_name              RF                  LCB              1
# 4  dataset_name              RF                  LCB              5
# 1  dataset_name              RF                  LCB              4
# 0  dataset_name              RF                  LCB              7
# 2  dataset_name              RF                  LCB              5
#
#           time  Median(model_runs)  Mean(model_runs)  \
# 3   943.026366            0.601655          0.595579
# 4  1032.986445            0.588372          0.591804
# 1   336.492251            0.576237          0.582421
# 0   419.437063            0.578174          0.578719
# 2   829.656851            0.568496          0.575207
#
#    Standard_Deviation(model_runs)  chunksize  h_max_iter  h_stop_condition  \
# 3                        0.020954       1360          92          0.009170
# 4                        0.006343       5629          54          0.007353
# 1                        0.012529       9225          31          0.007002
# 0                        0.002948       7825          37          0.007505
# 2                        0.011702       5629          54          0.007353
#
#       kappa  minimum_probability  num_topics  passes  w_max_iter  \
# 3  0.807165             0.081825          40     443         109
# 4  0.815760             0.056435          50     447         179
# 1  0.836720             0.092007          20     178         486
# 0  0.849872             0.049999          10     236         491
# 2  0.815760             0.056435          30     447         179
#
#    w_stop_condition  Coherence(not optimized)  Topic diversity(not optimized)
# 3          0.000352                  0.052257                        0.702500
# 4          0.000813                  0.035367                        0.684000
# 1          0.000689                 -0.034840                        0.715000
# 0          0.000854                 -0.051151                        0.750000
# 2          0.000813                 -0.038751                        0.696667

# %%
# Get ProdLDA best hyperparameters
prodlda_pl_df = get_best_df("prodlda", "pl_3723_2019")
prodlda_pl_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 1  dataset_name              RF                  LCB              7
# 2  dataset_name              RF                  LCB              1
# 0  dataset_name              RF                  LCB              9
# 3  dataset_name              RF                  LCB              7
# 4  dataset_name              RF                  LCB              9
#
#          time  Median(model_runs)  Mean(model_runs)  \
# 1   18.281430            0.569025          0.566211
# 2   17.259540            0.566710          0.558785
# 0  214.915105            0.551473          0.552922
# 3  693.069219            0.556317          0.552101
# 4  109.200047            0.546379          0.542963
#
#    Standard_Deviation(model_runs) activation   dropout        lr  momentum  \
# 1                        0.007137       relu  0.266380  0.009618  0.897813
# 2                        0.012177   softplus  0.705528  0.007475  0.550202
# 0                        0.002179   softplus  0.816766  0.008390  0.687112
# 3                        0.013977       relu  0.266380  0.009618  0.897813
# 4                        0.005710   softplus  0.874888  0.005326  0.678754
#
#    num_epochs  num_layers  num_neurons  num_samples  num_topics solver  \
# 1          74           1          580           42          20    sgd
# 2         134           5          392           34          30    sgd
# 0         409           2          350           49          10   adam
# 3          74           1          580           42          40    sgd
# 4         266           4          331           27          50    sgd
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 1                 -0.125793                        0.795000
# 2                 -0.164152                        0.853333
# 0                 -0.169552                        0.820000
# 3                 -0.114227                        0.745000
# 4                 -0.176594                        0.812000

# %% [markdown]
# # Visualize - PEC 471/2005

# %%
# Get CTM best hyperparameters
ctm_pec_df = get_best_df("ctm", "pec_471_2005")
ctm_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 2  dataset_name              RF                  LCB              8
# 3  dataset_name              RF                  LCB              9
# 4  dataset_name              RF                  LCB              9
# 1  dataset_name              RF                  LCB              5
# 0  dataset_name              RF                  LCB              6
#
#         time  Median(model_runs)  Mean(model_runs)  \
# 2  20.962127            0.554368          0.553415
# 3  18.139311            0.554548          0.548790
# 4  25.456002            0.549203          0.546692
# 1  16.641629            0.535274          0.535867
# 0  28.694756            0.517234          0.516988
#
#    Standard_Deviation(model_runs) activation   dropout inference_type  \
# 2                        0.023603    sigmoid  0.222712       combined
# 3                        0.011307      rrelu  0.733700       zeroshot
# 4                        0.021639       selu  0.145278       combined
# 1                        0.011771      rrelu  0.339496       zeroshot
# 0                        0.001951  leakyrelu  0.138377       combined
#
#   model_type  num_epochs  num_layers  num_neurons  num_samples  num_topics  \
# 2    prodLDA         324           4          100           50          30
# 3        LDA         304           3          200           45          40
# 4    prodLDA         475           2           50           45          50
# 1    prodLDA         118           4           50           49          20
# 0    prodLDA         359           1          300           48          10
#
#   solver  Coherence(not optimized)  Topic diversity(not optimized)
# 2    sgd                 -0.140262                           0.790
# 3    sgd                 -0.169758                           0.815
# 4    sgd                 -0.119633                           0.730
# 1    sgd                 -0.230781                           0.880
# 0    sgd                 -0.283527                           0.930

# %%
# Get ETM best hyperparameters
etm_pec_df = get_best_df("etm", "pec_471_2005")
etm_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              9
# 1  dataset_name              RF                  LCB              4
# 2  dataset_name              RF                  LCB              1
# 3  dataset_name              RF                  LCB              1
# 4  dataset_name              RF                  LCB              1
#
#          time  Median(model_runs)  Mean(model_runs)  \
# 0  126.946013            0.432631          0.430806
# 1  123.044231            0.417897          0.416041
# 2  183.293477            0.404854          0.404556
# 3  188.099021            0.390607          0.391055
# 4  201.582606            0.379700          0.380264
#
#    Standard_Deviation(model_runs) activation   dropout  num_epochs  \
# 0                        0.003768       relu  0.819490         227
# 1                        0.003818   softplus  0.900379         274
# 2                        0.004773       relu  0.705528         357
# 3                        0.000900       relu  0.705528         357
# 4                        0.001249       relu  0.705528         357
#
#    num_neurons  num_topics optimizer  rho  t_hidden_size  \
# 0          100          10  adadelta  223            874
# 1          100          20      asgd  367            471
# 2          200          30  adadelta  245            775
# 3          200          40  adadelta  245            775
# 4          200          50  adadelta  245            775
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 0                 -0.302770                           0.570
# 1                 -0.371115                           0.630
# 2                 -0.413784                           0.680
# 3                 -0.482816                           0.795
# 4                 -0.504805                           0.814

# %%
# Get HDP best hyperparameters
hdp_pec_df = get_best_df("hdp", "pec_471_2005", use_topics=False)
hdp_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              7
# 1  dataset_name              RF                  LCB              7
# 2  dataset_name              RF                  LCB              7
# 3  dataset_name              RF                  LCB              7
# 4  dataset_name              RF                  LCB              7
#
#         time  Median(model_runs)  Mean(model_runs)  \
# 0  18.734225            0.403176          0.402933
# 1  18.734225            0.403176          0.402933
# 2  18.734225            0.403176          0.402933
# 3  18.734225            0.403176          0.402933
# 4  18.734225            0.403176          0.402933
#
#    Standard_Deviation(model_runs)    kappa       tau  \
# 0                        0.001337  0.66803  8.229062
# 1                        0.001337  0.66803  8.229062
# 2                        0.001337  0.66803  8.229062
# 3                        0.001337  0.66803  8.229062
# 4                        0.001337  0.66803  8.229062
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 0                  -0.39879                           0.612
# 1                  -0.39879                           0.612
# 2                  -0.39879                           0.612
# 3                  -0.39879                           0.612
# 4                  -0.39879                           0.612

# %%
# Get LDA best hyperparameters
lda_pec_df = get_best_df("lda", "pec_471_2005")
lda_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 1  dataset_name              RF                  LCB              0
# 0  dataset_name              RF                  LCB              4
# 2  dataset_name              RF                  LCB              5
# 3  dataset_name              RF                  LCB              2
# 4  dataset_name              RF                  LCB              2
#
#          time  Median(model_runs)  Mean(model_runs)  \
# 1   55.186172            0.612513          0.616814
# 0  268.010310            0.623209          0.614770
# 2  326.157101            0.588100          0.598738
# 3  187.250630            0.571119          0.572146
# 4  205.281859            0.565017          0.559815
#
#    Standard_Deviation(model_runs)       alpha  chunksize     decay  \
# 1                        0.010885  asymmetric      41715  0.534526
# 0                        0.053697  asymmetric       7993  0.723881
# 2                        0.027171  asymmetric      15623  0.875413
# 3                        0.008345   symmetric      22107  0.518447
# 4                        0.008966   symmetric      22107  0.518447
#
#    gamma_threshold  iterations  num_topics    offset  passes  \
# 1         0.320128         488          20  2.203020      84
# 0         0.186447         650          10  9.408266     433
# 2         0.054385         632          30  5.997963     428
# 3         0.595289         470          40  3.999333     264
# 4         0.595289         470          50  3.999333     264
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 1                 -0.036033                          0.8500
# 0                  0.046849                          0.7700
# 2                  0.007209                          0.7500
# 3                 -0.106120                          0.8225
# 4                 -0.099284                          0.7560

# %%
# Get LSI best hyperparameters
lsi_pec_df = get_best_df("lsi", "pec_471_2005")
lsi_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              7
# 1  dataset_name              RF                  LCB              8
# 2  dataset_name              RF                  LCB              1
# 3  dataset_name              RF                  LCB              5
# 4  dataset_name              RF                  LCB              8
#
#         time  Median(model_runs)  Mean(model_runs)  \
# 0  15.195222            0.492293          0.489481
# 1  28.068654            0.422516          0.422078
# 2  41.530271            0.381461          0.380889
# 3  54.425396            0.340164          0.342066
# 4  67.698950            0.331443          0.329540
#
#    Standard_Deviation(model_runs)  chunksize     decay  extra_samples  \
# 0                        0.011413      14365  0.616962            144
# 1                        0.013739      31512  0.815253             19
# 2                        0.000891      16295  0.647302            174
# 3                        0.007053       7655  0.959472             31
# 4                        0.010237       1688  0.981793             22
#
#    num_topics  Coherence(not optimized)  Topic diversity(not optimized)
# 0          10                 -0.065220                        0.520000
# 1          20                 -0.128358                        0.410000
# 2          30                 -0.171093                        0.353333
# 3          40                 -0.222919                        0.302500
# 4          50                 -0.259500                        0.300000

# %%
# Get NeuralLDA best hyperparameters
neurallda_pec_df = get_best_df("neurallda", "pec_471_2005")
neurallda_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 4  dataset_name              RF                  LCB              7
# 1  dataset_name              RF                  LCB              7
# 3  dataset_name              RF                  LCB              7
# 2  dataset_name              RF                  LCB              7
# 0  dataset_name              RF                  LCB              6
#
#         time  Median(model_runs)  Mean(model_runs)  \
# 4  21.426088            0.552825          0.547277
# 1  20.151407            0.531959          0.534612
# 3  19.499985            0.532930          0.532157
# 2  15.467923            0.526579          0.531731
# 0  18.641490            0.489514          0.490153
#
#    Standard_Deviation(model_runs) activation   dropout        lr  momentum  \
# 4                        0.012768   softplus  0.266380  0.009618  0.897813
# 1                        0.004213   softplus  0.266380  0.009618  0.897813
# 3                        0.011440   softplus  0.266380  0.009618  0.897813
# 2                        0.011457   softplus  0.266380  0.009618  0.897813
# 0                        0.007994       relu  0.147565  0.004482  0.841802
#
#    num_epochs  num_layers  num_neurons  num_samples  num_topics solver  \
# 4          74           1          580           42          50   adam
# 1          74           1          580           42          20   adam
# 3          74           1          580           42          40   adam
# 2          74           1          580           42          30   adam
# 0         257           3          792           37          10    sgd
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 4                 -0.196502                        0.870000
# 1                 -0.254604                        0.925000
# 3                 -0.239324                        0.890000
# 2                 -0.260138                        0.913333
# 0                 -0.349717                        0.960000

# %%
# Get NMF best hyperparameters
nmf_pec_df = get_best_df("nmf", "pec_471_2005")
nmf_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 0  dataset_name              RF                  LCB              0
# 2  dataset_name              RF                  LCB              2
# 1  dataset_name              RF                  LCB              5
# 4  dataset_name              RF                  LCB              5
# 3  dataset_name              RF                  LCB              7
#
#          time  Median(model_runs)  Mean(model_runs)  \
# 0   50.622741            0.602489          0.599376
# 2  116.571098            0.591433          0.594204
# 1  203.840664            0.580978          0.585311
# 4  240.655395            0.582812          0.584749
# 3  212.036629            0.579851          0.582878
#
#    Standard_Deviation(model_runs)  chunksize  h_max_iter  h_stop_condition  \
# 0                        0.010553       4820          85          0.001621
# 2                        0.004278       5273          80          0.009716
# 1                        0.006213       5629          54          0.007353
# 4                        0.002792       5629          54          0.007353
# 3                        0.012854       6693          64          0.007750
#
#       kappa  minimum_probability  num_topics  passes  w_max_iter  \
# 0  0.659724             0.053667          10     107         167
# 2  0.662757             0.057977          30     224         483
# 1  0.815760             0.056435          20     447         179
# 4  0.815760             0.056435          50     447         179
# 3  0.730072             0.030988          40     401         111
#
#    w_stop_condition  Coherence(not optimized)  Topic diversity(not optimized)
# 0          0.000259                 -0.001883                        0.760000
# 2          0.000852                  0.005462                        0.726667
# 1          0.000813                 -0.024705                        0.725000
# 4          0.000813                  0.038024                        0.674000
# 3          0.000424                  0.010828                        0.680000

# %%
# Get ProdLDA best hyperparameters
prodlda_pec_df = get_best_df("prodlda", "pec_471_2005")
prodlda_pec_df
# Out:
#         dataset surrogate model acquisition function  num_iteration  \
# 4  dataset_name              RF                  LCB              7
# 3  dataset_name              RF                  LCB              7
# 2  dataset_name              RF                  LCB              7
# 0  dataset_name              RF                  LCB              7
# 1  dataset_name              RF                  LCB              7
#
#         time  Median(model_runs)  Mean(model_runs)  \
# 4  22.548415            0.642022          0.643323
# 3  20.963147            0.635366          0.640111
# 2  21.374371            0.605337          0.608147
# 0  17.498507            0.603172          0.602726
# 1  21.607066            0.595421          0.593876
#
#    Standard_Deviation(model_runs) activation   dropout        lr  momentum  \
# 4                        0.001986   softplus  0.266380  0.009618  0.897813
# 3                        0.011816   softplus  0.266380  0.009618  0.897813
# 2                        0.004622   softplus  0.266380  0.009618  0.897813
# 0                        0.013716   softplus  0.266380  0.009618  0.897813
# 1                        0.003737   softplus  0.245056  0.004834  0.883513
#
#    num_epochs  num_layers  num_neurons  num_samples  num_topics solver  \
# 4          74           1          580           42          50   adam
# 3          74           1          580           42          40   adam
# 2          74           1          580           42          30   adam
# 0          74           1          580           42          10   adam
# 1         397           1          900           32          20   adam
#
#    Coherence(not optimized)  Topic diversity(not optimized)
# 4                 -0.021763                           0.934
# 3                 -0.037662                           0.935
# 2                 -0.102606                           0.930
# 0                 -0.116285                           0.990
# 1                 -0.126328                           0.945

# %% [markdown]
# # Training best models

# %%
model_names = ["CTM", "ETM", "HDP", "LDA", "LSI", "NeuralLDA", "NMF", "ProdLDA", "BERTopic", "Top2Vec"]

# %%
def eval_model(model, dataset, tdci, td, tc):
    """
    Evaluate a model using the metrics defined in the beginning of this notebook.

    Returns:
        tdci_results: TDCI score
        coherence_results: Coherence score
        diversity_results: Diversity score
        topics: Topics
        wall_time: Wall time
    """

    res = dict()

    try:
        start = time.time()
        results = model.train_model(dataset)
        end = time.time()

        coherence_results = tc.score(results)
        diversity_results = td.score(results)
        tdci_results = tdci.score(results)

        remove_unused()

        res['tdci'] = tdci_results
        res['coherence'] = coherence_results
        res['diversity'] = diversity_results
        res['topics'] = len(results['topics'])
        res['wall_time'] = end - start
    
    except:

        remove_unused()
        res['tdci'] = 0
        res['coherence'] = 0
        res['diversity'] = 0
        res['topics'] = 0
        res['wall_time'] = 0

    return res

# %% [markdown]
# ## PL

# %%
ctm_pl_model = CTM(**get_hyperparams(ctm_pl_df))
etm_pl_model = ETM(**get_hyperparams(etm_pl_df.drop(columns=['num_neurons', 'rho'])))
hdp_pl_model = HDP(**get_hyperparams(hdp_pl_df))
lda_pl_model = LDA(**get_hyperparams(lda_pl_df))
lsi_pl_model = LSI(**get_hyperparams(lsi_pl_df))
neurallda_pl_model = NeuralLDA(**get_hyperparams(neurallda_pl_df))
nmf_pl_model = NMF(**get_hyperparams(nmf_pl_df))
prodlda_pl_model = ProdLDA(**get_hyperparams(prodlda_pl_df))
bertopic_pl_model = CustomBERTopic()
top2vec_pl_model = CustomTop2Vec()

pl_models = [ctm_pl_model, etm_pl_model, hdp_pl_model, lda_pl_model, lsi_pl_model, neurallda_pl_model, nmf_pl_model, prodlda_pl_model, bertopic_pl_model, top2vec_pl_model]

# %%
# %%capture

df_test_pl = pd.DataFrame(
    {"Model": [], "TDCI": [], "TD": [], "TC": [], "Topics": [], "Wall time": []})

for i in range(10):
    print("=============")
    print("Iteration" +  str(i))
    print("=============")
    
    for model, name in zip(pl_models, model_names):
        res = eval_model(model, dataset_pl, tdci_pl_metric, td_pl_metric, tc_pl_metric)

        df_test_pl.loc[len(df_test_pl)] = [name, res['tdci'], res['diversity'], res['coherence'], res['topics'], res['wall_time']]
# Out:
# =============
# Iteration0
# =============
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# model: ETM(
#   (t_drop): Dropout(p=0.3077499918792237, inplace=False)
#   (theta_act): ReLU()
#   (rho): Linear(in_features=300, out_features=2131, bias=False)
#   (alphas): Linear(in_features=300, out_features=10, bias=False)
#   (q_theta): Sequential(
#     (0): Linear(in_features=2131, out_features=487, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=487, out_features=487, bias=True)
#     (3): ReLU()
#   )
#   (mu_q_theta): Linear(in_features=487, out_features=10, bias=True)
#   (logsigma_q_theta): Linear(in_features=487, out_features=10, bias=True)
# )
# ****************************************************************************************************
# Epoch----->1 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (inf --> 72.661613).  Saving model ...
# ****************************************************************************************************
# Epoch----->2 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.661613 --> 72.660454).  Saving model ...
# ****************************************************************************************************
# Epoch----->3 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.660454 --> 72.659309).  Saving model ...
# ****************************************************************************************************
# Epoch----->4 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.659309 --> 72.658188).  Saving model ...
# ****************************************************************************************************
# Epoch----->5 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.658188 --> 72.657082).  Saving model ...
# ****************************************************************************************************
# Epoch----->6 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.657082 --> 72.655983).  Saving model ...
# ****************************************************************************************************
# Epoch----->7 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.655983 --> 72.654907).  Saving model ...
# ****************************************************************************************************
# Epoch----->8 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.654907 --> 72.653831).  Saving model ...
# ****************************************************************************************************
# Epoch----->9 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 79.69 .. NELBO: 79.7
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.653831 --> 72.652786).  Saving model ...
# ****************************************************************************************************
# Epoch----->10 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.69 .. NELBO: 79.69
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.652786 --> 72.651756).  Saving model ...
# ****************************************************************************************************
# Epoch----->11 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.69 .. NELBO: 79.69
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.651756 --> 72.650711).  Saving model ...
# ****************************************************************************************************
# Epoch----->12 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.69 .. NELBO: 79.69
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.650711 --> 72.649689).  Saving model ...
# ****************************************************************************************************
# Epoch----->13 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.69 .. NELBO: 79.69
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.649689 --> 72.648682).  Saving model ...
# ****************************************************************************************************
# Epoch----->14 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.648682 --> 72.647667).  Saving model ...
# ****************************************************************************************************
# Epoch----->15 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.647667 --> 72.646683).  Saving model ...
# ****************************************************************************************************
# Epoch----->16 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.646683 --> 72.645691).  Saving model ...
# ****************************************************************************************************
# Epoch----->17 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.645691 --> 72.644714).  Saving model ...
# ****************************************************************************************************
# Epoch----->18 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.644714 --> 72.643745).  Saving model ...
# ****************************************************************************************************
# Epoch----->19 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.643745 --> 72.642784).  Saving model ...
# ****************************************************************************************************
# Epoch----->20 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.642784 --> 72.641823).  Saving model ...
# ****************************************************************************************************
# Epoch----->21 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.68 .. NELBO: 79.68
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.641823 --> 72.640862).  Saving model ...
# ****************************************************************************************************
# Epoch----->22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.640862 --> 72.639908).  Saving model ...
# ****************************************************************************************************
# Epoch----->23 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.639908 --> 72.638969).  Saving model ...
# ****************************************************************************************************
# Epoch----->24 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.638969 --> 72.638023).  Saving model ...
# ****************************************************************************************************
# Epoch----->25 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.638023 --> 72.637093).  Saving model ...
# ****************************************************************************************************
# Epoch----->26 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.637093 --> 72.636147).  Saving model ...
# ****************************************************************************************************
# Epoch----->27 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.636147 --> 72.635223).  Saving model ...
# ****************************************************************************************************
# Epoch----->28 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.635223 --> 72.634285).  Saving model ...
# ****************************************************************************************************
# Epoch----->29 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.634285 --> 72.633362).  Saving model ...
# ****************************************************************************************************
# Epoch----->30 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.633362 --> 72.632423).  Saving model ...
# ****************************************************************************************************
# Epoch----->31 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.632423 --> 72.631508).  Saving model ...
# ****************************************************************************************************
# Epoch----->32 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.631508 --> 72.630577).  Saving model ...
# ****************************************************************************************************
# Epoch----->33 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.67 .. NELBO: 79.67
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.630577 --> 72.629669).  Saving model ...
# ****************************************************************************************************
# Epoch----->34 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.629669 --> 72.628738).  Saving model ...
# ****************************************************************************************************
# Epoch----->35 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.628738 --> 72.627823).  Saving model ...
# ****************************************************************************************************
# Epoch----->36 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.627823 --> 72.626907).  Saving model ...
# ****************************************************************************************************
# Epoch----->37 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.626907 --> 72.625984).  Saving model ...
# ****************************************************************************************************
# Epoch----->38 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.625984 --> 72.625076).  Saving model ...
# ****************************************************************************************************
# Epoch----->39 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.625076 --> 72.624153).  Saving model ...
# ****************************************************************************************************
# Epoch----->40 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.624153 --> 72.623222).  Saving model ...
# ****************************************************************************************************
# Epoch----->41 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.623222 --> 72.622307).  Saving model ...
# ****************************************************************************************************
# Epoch----->42 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.16 .. NELBO: 18.16
# ****************************************************************************************************
# Validation loss decreased (72.622307 --> 72.621399).  Saving model ...
# ****************************************************************************************************
# Epoch----->43 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.621399 --> 72.620476).  Saving model ...
# ****************************************************************************************************
# Epoch----->44 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.66 .. NELBO: 79.66
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.620476 --> 72.619537).  Saving model ...
# ****************************************************************************************************
# Epoch----->45 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.619537 --> 72.618607).  Saving model ...
# ****************************************************************************************************
# Epoch----->46 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.618607 --> 72.617691).  Saving model ...
# ****************************************************************************************************
# Epoch----->47 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.617691 --> 72.616760).  Saving model ...
# ****************************************************************************************************
# Epoch----->48 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.616760 --> 72.615829).  Saving model ...
# ****************************************************************************************************
# Epoch----->49 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.615829 --> 72.614891).  Saving model ...
# ****************************************************************************************************
# Epoch----->50 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.614891 --> 72.613960).  Saving model ...
# ****************************************************************************************************
# Epoch----->51 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.613960 --> 72.613014).  Saving model ...
# ****************************************************************************************************
# Epoch----->52 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.613014 --> 72.612083).  Saving model ...
# ****************************************************************************************************
# Epoch----->53 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.612083 --> 72.611130).  Saving model ...
# ****************************************************************************************************
# Epoch----->54 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.611130 --> 72.610184).  Saving model ...
# ****************************************************************************************************
# Epoch----->55 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.65 .. NELBO: 79.65
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.610184 --> 72.609245).  Saving model ...
# ****************************************************************************************************
# Epoch----->56 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.609245 --> 72.608292).  Saving model ...
# ****************************************************************************************************
# Epoch----->57 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.608292 --> 72.607323).  Saving model ...
# ****************************************************************************************************
# Epoch----->58 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.607323 --> 72.606377).  Saving model ...
# ****************************************************************************************************
# Epoch----->59 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.606377 --> 72.605408).  Saving model ...
# ****************************************************************************************************
# Epoch----->60 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.605408 --> 72.604439).  Saving model ...
# ****************************************************************************************************
# Epoch----->61 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.604439 --> 72.603462).  Saving model ...
# ****************************************************************************************************
# Epoch----->62 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.603462 --> 72.602478).  Saving model ...
# ****************************************************************************************************
# Epoch----->63 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.64 .. NELBO: 79.64
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.602478 --> 72.601509).  Saving model ...
# ****************************************************************************************************
# Epoch----->64 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.601509 --> 72.600517).  Saving model ...
# ****************************************************************************************************
# Epoch----->65 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.600517 --> 72.599518).  Saving model ...
# ****************************************************************************************************
# Epoch----->66 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.599518 --> 72.598518).  Saving model ...
# ****************************************************************************************************
# Epoch----->67 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.598518 --> 72.597511).  Saving model ...
# ****************************************************************************************************
# Epoch----->68 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.597511 --> 72.596497).  Saving model ...
# ****************************************************************************************************
# Epoch----->69 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.596497 --> 72.595497).  Saving model ...
# ****************************************************************************************************
# Epoch----->70 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.595497 --> 72.594475).  Saving model ...
# ****************************************************************************************************
# Epoch----->71 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.594475 --> 72.593445).  Saving model ...
# ****************************************************************************************************
# Epoch----->72 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.593445 --> 72.592415).  Saving model ...
# ****************************************************************************************************
# Epoch----->73 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.592415 --> 72.591362).  Saving model ...
# ****************************************************************************************************
# Epoch----->74 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.63 .. NELBO: 79.63
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.591362 --> 72.590324).  Saving model ...
# ****************************************************************************************************
# Epoch----->75 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.62 .. NELBO: 79.62
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.15 .. NELBO: 18.15
# ****************************************************************************************************
# Validation loss decreased (72.590324 --> 72.589279).  Saving model ...
# ...
# Validation loss decreased (72.499756 --> 72.497871).  Saving model ...
# ****************************************************************************************************
# Epoch----->128 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.51 .. NELBO: 79.51
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.497871 --> 72.495979).  Saving model ...
# ****************************************************************************************************
# Epoch----->129 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.51 .. NELBO: 79.51
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.495979 --> 72.494064).  Saving model ...
# ****************************************************************************************************
# Epoch----->130 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.51 .. NELBO: 79.51
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.494064 --> 72.492142).  Saving model ...
# ****************************************************************************************************
# Epoch----->131 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.51 .. NELBO: 79.51
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.492142 --> 72.490204).  Saving model ...
# ****************************************************************************************************
# Epoch----->132 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.51 .. NELBO: 79.51
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.490204 --> 72.488228).  Saving model ...
# ****************************************************************************************************
# Epoch----->133 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.5 .. NELBO: 79.5
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.488228 --> 72.486244).  Saving model ...
# ****************************************************************************************************
# Epoch----->134 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.5 .. NELBO: 79.5
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.486244 --> 72.484238).  Saving model ...
# ****************************************************************************************************
# Epoch----->135 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.5 .. NELBO: 79.5
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.484238 --> 72.482224).  Saving model ...
# ****************************************************************************************************
# Epoch----->136 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.5 .. NELBO: 79.5
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.482224 --> 72.480179).  Saving model ...
# ****************************************************************************************************
# Epoch----->137 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 79.49 .. NELBO: 79.49
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 18.12 .. NELBO: 18.12
# ****************************************************************************************************
# Validation loss decreased (72.480179 --> 72.478111).  Saving model ...
# Epoch: [1/348]	Samples: [493/171564]	Train Loss: 103.20704907771298	Time: 0:00:00.899582
# Epoch: [1/348]	Samples: [106/36888]	Validation Loss: 101.89882443985849	Time: 0:00:00.069143
# Epoch: [2/348]	Samples: [986/171564]	Train Loss: 108.57497246608773	Time: 0:00:00.661032
# Epoch: [2/348]	Samples: [106/36888]	Validation Loss: 80.89675615418632	Time: 0:00:00.043086
# Epoch: [3/348]	Samples: [1479/171564]	Train Loss: 103.53647351990365	Time: 0:00:00.844675
# Epoch: [3/348]	Samples: [106/36888]	Validation Loss: 81.71580649321933	Time: 0:00:00.066695
# Epoch: [4/348]	Samples: [1972/171564]	Train Loss: 103.44497377345334	Time: 0:00:00.660861
# Epoch: [4/348]	Samples: [106/36888]	Validation Loss: 75.32688587116745	Time: 0:00:00.070401
# Epoch: [5/348]	Samples: [2465/171564]	Train Loss: 100.25912778904666	Time: 0:00:00.842527
# Epoch: [5/348]	Samples: [106/36888]	Validation Loss: 74.23007720371463	Time: 0:00:00.056194
# Epoch: [6/348]	Samples: [2958/171564]	Train Loss: 102.65896872622972	Time: 0:00:00.671884
# Epoch: [6/348]	Samples: [106/36888]	Validation Loss: 74.61993984006486	Time: 0:00:00.038658
# Epoch: [7/348]	Samples: [3451/171564]	Train Loss: 100.83600286828093	Time: 0:00:00.584667
# Epoch: [7/348]	Samples: [106/36888]	Validation Loss: 75.40063015919812	Time: 0:00:00.077213
# %%
df_test_pl
# df_res_pl.sort_values(by="TDCI", ascending=False)
# Out:
#         Model      TDCI        TD        TC  Topics  Wall time
# 0         CTM  0.587938  0.970000 -0.156401      10  33.309069
# 1         ETM  0.406973  0.720000 -0.432695      10  21.732535
# 2         HDP  0.362880  0.672667 -0.503087     150   2.481196
# 3         LDA  0.607995  0.960000 -0.110255      10  47.891599
# 4         LSI  0.473292  0.450000 -0.001747      10   4.647422
# ..        ...       ...       ...       ...     ...        ...
# 95  NeuralLDA  0.486947  0.710000 -0.258923      10  45.470150
# 96        NMF  0.589455  0.720000 -0.002033      10  35.767473
# 97    ProdLDA  0.563908  0.840000 -0.151176      10  15.460773
# 98   BERTopic  0.556847  0.742857 -0.109328      14  23.315608
# 99    Top2Vec  0.500638  0.500000  0.002556       2   4.341439
#
# [100 rows x 6 columns]

# %% [markdown]
# ## PEC

# %%
ctm_pec_model = CTM(**get_hyperparams(ctm_pec_df))
etm_pec_model = ETM(**get_hyperparams(etm_pec_df.drop(columns=['num_neurons', 'rho'])))
hdp_pec_model = HDP(**get_hyperparams(hdp_pec_df))
lda_pec_model = LDA(**get_hyperparams(lda_pec_df))
lsi_pec_model = LSI(**get_hyperparams(lsi_pec_df))
neurallda_pec_model = NeuralLDA(**get_hyperparams(neurallda_pec_df))
nmf_pec_model = NMF(**get_hyperparams(nmf_pec_df))
prodlda_pec_model = ProdLDA(**get_hyperparams(prodlda_pec_df))
bertopic_pec_model = CustomBERTopic()
top2vec_pec_model = CustomTop2Vec()

pec_models = [ctm_pec_model, etm_pec_model, hdp_pec_model, lda_pec_model, lsi_pec_model, neurallda_pec_model, nmf_pec_model, prodlda_pec_model, bertopic_pec_model, top2vec_pec_model]

# %%
# %%capture

df_test_pec = pd.DataFrame(
    {"Model": [], "TDCI": [], "TD": [], "TC": [], "Topics": [], "Wall time": []})

for i in range(10):
    print("=============")
    print("Iteration" +  str(i))
    print("=============")
    
    for model, name in zip(pec_models, model_names):
        res = eval_model(model, dataset_pec, tdci_pec_metric, td_pec_metric, tc_pec_metric)

        df_test_pec.loc[len(df_test_pec)] = [name, res['tdci'], res['diversity'], res['coherence'], res['topics'], res['wall_time']]
# Out:
# =============
# Iteration0
# =============
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# model: ETM(
#   (t_drop): Dropout(p=0.819490298345925, inplace=False)
#   (theta_act): ReLU()
#   (rho): Linear(in_features=300, out_features=2088, bias=False)
#   (alphas): Linear(in_features=300, out_features=10, bias=False)
#   (q_theta): Sequential(
#     (0): Linear(in_features=2088, out_features=874, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=874, out_features=874, bias=True)
#     (3): ReLU()
#   )
#   (mu_q_theta): Linear(in_features=874, out_features=10, bias=True)
#   (logsigma_q_theta): Linear(in_features=874, out_features=10, bias=True)
# )
# ****************************************************************************************************
# Epoch----->1 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.28 .. NELBO: 86.29
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (inf --> 87.038986).  Saving model ...
# ****************************************************************************************************
# Epoch----->2 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.28 .. NELBO: 86.29
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.038986 --> 87.038513).  Saving model ...
# ****************************************************************************************************
# Epoch----->3 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.038513 --> 87.038025).  Saving model ...
# ****************************************************************************************************
# Epoch----->4 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.038025 --> 87.037552).  Saving model ...
# ****************************************************************************************************
# Epoch----->5 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.037552 --> 87.037056).  Saving model ...
# ****************************************************************************************************
# Epoch----->6 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.037056 --> 87.036560).  Saving model ...
# ****************************************************************************************************
# Epoch----->7 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.036560 --> 87.036064).  Saving model ...
# ****************************************************************************************************
# Epoch----->8 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.036064 --> 87.035583).  Saving model ...
# ****************************************************************************************************
# Epoch----->9 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.035583 --> 87.035080).  Saving model ...
# ****************************************************************************************************
# Epoch----->10 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.035080 --> 87.034569).  Saving model ...
# ****************************************************************************************************
# Epoch----->11 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.034569 --> 87.034081).  Saving model ...
# ****************************************************************************************************
# Epoch----->12 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.034081 --> 87.033562).  Saving model ...
# ****************************************************************************************************
# Epoch----->13 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.033562 --> 87.033066).  Saving model ...
# ****************************************************************************************************
# Epoch----->14 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.033066 --> 87.032562).  Saving model ...
# ****************************************************************************************************
# Epoch----->15 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.032562 --> 87.032051).  Saving model ...
# ****************************************************************************************************
# Epoch----->16 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.032051 --> 87.031540).  Saving model ...
# ****************************************************************************************************
# Epoch----->17 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.031540 --> 87.031036).  Saving model ...
# ****************************************************************************************************
# Epoch----->18 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.031036 --> 87.030525).  Saving model ...
# ****************************************************************************************************
# Epoch----->19 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.030525 --> 87.030014).  Saving model ...
# ****************************************************************************************************
# Epoch----->20 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.030014 --> 87.029510).  Saving model ...
# ****************************************************************************************************
# Epoch----->21 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.029510 --> 87.028992).  Saving model ...
# ****************************************************************************************************
# Epoch----->22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.26 .. NELBO: 86.27
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.028992 --> 87.028473).  Saving model ...
# ****************************************************************************************************
# Epoch----->23 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.26 .. NELBO: 86.27
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.028473 --> 87.027954).  Saving model ...
# ****************************************************************************************************
# Epoch----->24 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 86.27 .. NELBO: 86.28
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.027954 --> 87.027435).  Saving model ...
# ****************************************************************************************************
# Epoch----->25 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.027435 --> 87.026917).  Saving model ...
# ****************************************************************************************************
# Epoch----->26 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.026917 --> 87.026390).  Saving model ...
# ****************************************************************************************************
# Epoch----->27 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.026390 --> 87.025871).  Saving model ...
# ****************************************************************************************************
# Epoch----->28 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.025871 --> 87.025360).  Saving model ...
# ****************************************************************************************************
# Epoch----->29 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.025360 --> 87.024834).  Saving model ...
# ****************************************************************************************************
# Epoch----->30 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.024834 --> 87.024300).  Saving model ...
# ****************************************************************************************************
# Epoch----->31 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.024300 --> 87.023781).  Saving model ...
# ****************************************************************************************************
# Epoch----->32 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.023781 --> 87.023254).  Saving model ...
# ****************************************************************************************************
# Epoch----->33 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.76 .. NELBO: 21.76
# ****************************************************************************************************
# Validation loss decreased (87.023254 --> 87.022728).  Saving model ...
# ****************************************************************************************************
# Epoch----->34 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.022728 --> 87.022209).  Saving model ...
# ****************************************************************************************************
# Epoch----->35 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.022209 --> 87.021683).  Saving model ...
# ****************************************************************************************************
# Epoch----->36 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.021683 --> 87.021149).  Saving model ...
# ****************************************************************************************************
# Epoch----->37 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.021149 --> 87.020615).  Saving model ...
# ****************************************************************************************************
# Epoch----->38 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.020615 --> 87.020096).  Saving model ...
# ****************************************************************************************************
# Epoch----->39 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.020096 --> 87.019562).  Saving model ...
# ****************************************************************************************************
# Epoch----->40 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.26 .. NELBO: 86.26
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.019562 --> 87.019020).  Saving model ...
# ****************************************************************************************************
# Epoch----->41 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.019020 --> 87.018486).  Saving model ...
# ****************************************************************************************************
# Epoch----->42 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.018486 --> 87.017960).  Saving model ...
# ****************************************************************************************************
# Epoch----->43 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.017960 --> 87.017418).  Saving model ...
# ****************************************************************************************************
# Epoch----->44 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.017418 --> 87.016884).  Saving model ...
# ****************************************************************************************************
# Epoch----->45 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.016884 --> 87.016342).  Saving model ...
# ****************************************************************************************************
# Epoch----->46 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.016342 --> 87.015808).  Saving model ...
# ****************************************************************************************************
# Epoch----->47 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.015808 --> 87.015274).  Saving model ...
# ****************************************************************************************************
# Epoch----->48 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.015274 --> 87.014732).  Saving model ...
# ****************************************************************************************************
# Epoch----->49 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.014732 --> 87.014183).  Saving model ...
# ****************************************************************************************************
# Epoch----->50 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.014183 --> 87.013649).  Saving model ...
# ****************************************************************************************************
# Epoch----->51 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.013649 --> 87.013092).  Saving model ...
# ****************************************************************************************************
# Epoch----->52 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.013092 --> 87.012550).  Saving model ...
# ****************************************************************************************************
# Epoch----->53 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.012550 --> 87.011993).  Saving model ...
# ****************************************************************************************************
# Epoch----->54 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.011993 --> 87.011452).  Saving model ...
# ****************************************************************************************************
# Epoch----->55 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.011452 --> 87.010910).  Saving model ...
# ****************************************************************************************************
# Epoch----->56 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.010910 --> 87.010345).  Saving model ...
# ****************************************************************************************************
# Epoch----->57 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.010345 --> 87.009804).  Saving model ...
# ****************************************************************************************************
# Epoch----->58 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.009804 --> 87.009262).  Saving model ...
# ****************************************************************************************************
# Epoch----->59 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.25 .. NELBO: 86.25
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.009262 --> 87.008682).  Saving model ...
# ****************************************************************************************************
# Epoch----->60 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.008682 --> 87.008141).  Saving model ...
# ****************************************************************************************************
# Epoch----->61 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.008141 --> 87.007576).  Saving model ...
# ****************************************************************************************************
# Epoch----->62 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.007576 --> 87.007027).  Saving model ...
# ****************************************************************************************************
# Epoch----->63 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.007027 --> 87.006470).  Saving model ...
# ****************************************************************************************************
# Epoch----->64 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.006470 --> 87.005905).  Saving model ...
# ****************************************************************************************************
# Epoch----->65 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.005905 --> 87.005325).  Saving model ...
# ****************************************************************************************************
# Epoch----->66 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.005325 --> 87.004776).  Saving model ...
# ****************************************************************************************************
# Epoch----->67 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.004776 --> 87.004181).  Saving model ...
# ****************************************************************************************************
# Epoch----->68 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.004181 --> 87.003624).  Saving model ...
# ****************************************************************************************************
# Epoch----->69 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.003624 --> 87.003059).  Saving model ...
# ****************************************************************************************************
# Epoch----->70 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.003059 --> 87.002480).  Saving model ...
# ****************************************************************************************************
# Epoch----->71 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.002480 --> 87.001915).  Saving model ...
# ****************************************************************************************************
# Epoch----->72 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.001915 --> 87.001335).  Saving model ...
# ****************************************************************************************************
# Epoch----->73 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.001335 --> 87.000755).  Saving model ...
# ****************************************************************************************************
# Epoch----->74 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.000755 --> 87.000168).  Saving model ...
# ****************************************************************************************************
# Epoch----->75 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.24 .. NELBO: 86.24
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.75 .. NELBO: 21.75
# ****************************************************************************************************
# Validation loss decreased (87.000168 --> 86.999588).  Saving model ...
# ...
# Epoch----->225 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.11 .. NELBO: 86.11
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.72 .. NELBO: 21.72
# ****************************************************************************************************
# Validation loss decreased (86.876747 --> 86.875488).  Saving model ...
# ****************************************************************************************************
# Epoch----->226 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 86.11 .. NELBO: 86.11
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.72 .. NELBO: 21.72
# ****************************************************************************************************
# Validation loss decreased (86.875488 --> 86.874237).  Saving model ...
# ****************************************************************************************************
# Epoch----->227 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss:
# Epoch: [34/74]	Samples: [95/7030]	Validation Loss: 85.13068976151315	Time: 0:00:00.056434
# Early stopping
# 2023-07-02 11:33:31,943 - top2vec - INFO - Pre-processing documents for training
# 2023-07-02 11:33:31,962 - top2vec - INFO - Creating joint document/word embedding
# 2023-07-02 11:33:33,217 - top2vec - INFO - Creating lower dimension embedding of documents
# 2023-07-02 11:33:35,931 - top2vec - INFO - Finding dense areas of documents
# 2023-07-02 11:33:35,947 - top2vec - INFO - Finding topics
# Dictionary<2088 unique tokens: ['constituição', 'jeitinho', 'permite', 'perpetradas', 'poder']...>

# %%
# Group by model name
df_test_pec
# df_res_pl.sort_values(by="TDCI", ascending=False)
# Out:
#         Model      TDCI     TD        TC  Topics  Wall time
# 0         CTM  0.476313  0.970 -0.368685      10  56.969265
# 1         ETM  0.428238  0.560 -0.306661      10  88.816237
# 2         HDP  0.404477  0.598 -0.388830     150   2.102899
# 3         LDA  0.561643  0.640  0.000759      10  87.566540
# 4         LSI  0.490693  0.520 -0.070975      10   4.518970
# ..        ...       ...    ...       ...     ...        ...
# 95  NeuralLDA  0.454034  0.970 -0.407236      10  42.102571
# 96        NMF  0.588357  0.770 -0.047889      10  14.651816
# 97    ProdLDA  0.588682  0.990 -0.162240      10  26.694775
# 98   BERTopic  0.584720  0.950 -0.155338       2  22.878505
# 99    Top2Vec  0.000000  0.000  0.000000       0   0.000000
#
# [100 rows x 6 columns]

# %%
df_test_pl.to_csv("../output/df_test_pl.csv")
df_test_pec.to_csv("../output/df_test_pec.csv")

# %%
df_test_pl.groupby("Model").mean().sort_values(by="TDCI", ascending=False)
# Out:
#                TDCI        TD        TC  Topics  Wall time
# Model
# LDA        0.632483  0.909000 -0.026446    10.0  48.126633
# NMF        0.575008  0.712000 -0.034624    10.0  35.097047
# BERTopic   0.561514  0.713982 -0.073307    12.8  23.201868
# ProdLDA    0.542806  0.803000 -0.175556    10.0  17.021340
# CTM        0.540694  0.955000 -0.245160    10.0  58.770410
# Top2Vec    0.504991  0.508333  0.014933     2.2   4.214841
# NeuralLDA  0.492641  0.781000 -0.279511    10.0  38.161214
# LSI        0.488238  0.482000 -0.008584    10.0   4.617779
# ETM        0.421657  0.640000 -0.367450    10.0  44.655613
# HDP        0.363819  0.679733 -0.503214   150.0   2.463859

# %%
df_test_pec.groupby("Model").mean().sort_values(by="TDCI", ascending=False)
# Out:
#                TDCI      TD        TC  Topics  Wall time
# Model
# LDA        0.627156  0.8040  0.033430    10.0  85.688585
# NMF        0.582347  0.7520 -0.048777    10.0  14.890337
# ProdLDA    0.577027  0.9740 -0.179949    10.0  21.579689
# BERTopic   0.575332  0.9500 -0.174652     2.0  22.955917
# CTM        0.488746  0.9380 -0.338625    10.0  62.228803
# LSI        0.486335  0.5070 -0.062256    10.0   4.508680
# NeuralLDA  0.480206  0.9750 -0.362790    10.0  36.000064
# ETM        0.430966  0.5820 -0.313383    10.0  89.375587
# HDP        0.401613  0.6056 -0.399027   150.0   2.090643
# Top2Vec    0.000000  0.0000  0.000000     0.0   0.000000

# %%
n_topics = 10

# %%
from octis.models.CTM import CTM
from octis.models.ETM import ETM
from octis.models.HDP import HDP
from octis.models.LDA import LDA
from octis.models.LSI import LSI
from octis.models.NMF import NMF
from octis.models.NeuralLDA import NeuralLDA
from octis.models.ProdLDA import ProdLDA
from octis.dataset.dataset import Dataset
from octis.evaluation_metrics.diversity_metrics import TopicDiversity
from octis.evaluation_metrics.coherence_metrics import Coherence

# %%
# Avoid warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Load dataset

# %%
# Define dataset
dataset = Dataset()
dataset.load_custom_dataset_from_folder("pl_3723_2019")

# %% [markdown]
# # Choosing best parameters

# %%
# TODO

# %%
import torch
import gc
# a = torch.zeros(3000000000, dtype=torch.int8)
# a = a.cuda()
# del a
torch.cuda.empty_cache()
gc.collect()
# Out:
# 24189

# %% [markdown]
# # Train models

# %%
# Train CTM
model_ctm = CTM(num_topics=n_topics)
output_ctm = model_ctm.train_model(dataset)
# Out:
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Train ETM
model_etm = ETM(num_topics=n_topics, device="gpu")
output_etm = model_etm.train_model(dataset)
# Out:
# model: ETM(
#   (t_drop): Dropout(p=0.5, inplace=False)
#   (theta_act): ReLU()
#   (rho): Linear(in_features=300, out_features=2131, bias=False)
#   (alphas): Linear(in_features=300, out_features=10, bias=False)
#   (q_theta): Sequential(
#     (0): Linear(in_features=2131, out_features=800, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=800, out_features=800, bias=True)
#     (3): ReLU()
#   )
#   (mu_q_theta): Linear(in_features=800, out_features=10, bias=True)
#   (logsigma_q_theta): Linear(in_features=800, out_features=10, bias=True)
# )
# ****************************************************************************************************
# Epoch----->1 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 77.79 .. NELBO: 77.8
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 21.28 .. NELBO: 21.28
# ****************************************************************************************************
# Validation loss decreased (inf --> 85.129257).  Saving model ...
# ****************************************************************************************************
# Epoch----->2 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 76.46 .. NELBO: 76.46
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 20.82 .. NELBO: 20.82
# ****************************************************************************************************
# Validation loss decreased (85.129257 --> 83.284744).  Saving model ...
# ****************************************************************************************************
# Epoch----->3 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 73.71 .. NELBO: 73.71
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 20.14 .. NELBO: 20.14
# ****************************************************************************************************
# Validation loss decreased (83.284744 --> 80.564766).  Saving model ...
# ****************************************************************************************************
# Epoch----->4 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 70.03 .. NELBO: 70.03
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 19.58 .. NELBO: 19.58
# ****************************************************************************************************
# Validation loss decreased (80.564766 --> 78.306152).  Saving model ...
# ****************************************************************************************************
# Epoch----->5 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 66.9 .. NELBO: 66.9
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 19.55 .. NELBO: 19.55
# ****************************************************************************************************
# Validation loss decreased (78.306152 --> 78.210938).  Saving model ...
# ****************************************************************************************************
# Epoch----->6 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 65.57 .. NELBO: 65.57
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 19.95 .. NELBO: 19.95
# ****************************************************************************************************
# EarlyStopping counter: 1 out of 5
# ****************************************************************************************************
# Epoch----->7 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 65.52 .. NELBO: 65.52
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 20.25 .. NELBO: 20.25
# ****************************************************************************************************
# EarlyStopping counter: 2 out of 5
# ****************************************************************************************************
# Epoch----->8 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 65.29 .. NELBO: 65.3
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 20.17 .. NELBO: 20.17
# ****************************************************************************************************
# EarlyStopping counter: 3 out of 5
# ****************************************************************************************************
# Epoch----->9 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 64.8 .. NELBO: 64.81
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 20.11 .. NELBO: 20.11
# ****************************************************************************************************
# EarlyStopping counter: 4 out of 5
# ****************************************************************************************************
# Epoch----->10 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 64.78 .. NELBO: 64.79
# ****************************************************************************************************
# ****************************************************************************************************
# VALIDATION .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 20.15 .. NELBO: 20.15
# ****************************************************************************************************
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
# Train HDP
model_hdp = HDP()
output_hdp = model_hdp.train_model(dataset)

# %%
# Train LDA
model_lda = LDA(num_topics=n_topics, iterations=500, passes=5)
output_lda = model_lda.train_model(dataset)

# %%
# Train LSI
model_lsi = LSI(num_topics=n_topics)
output_lsi = model_lsi.train_model(dataset)

# %%
# Train NMF
model_nmf = NMF(num_topics=n_topics)
output_nmf = model_nmf.train_model(dataset)

# %%
# Train NeuralLDA
model_nlda = NeuralLDA(num_topics=n_topics)
output_nlda = model_nlda.train_model(dataset)
# Out:
# Epoch: [1/100]	Samples: [493/49300]	Train Loss: 89.41488554608266	Time: 0:00:00.044444
# Epoch: [1/100]	Samples: [106/10600]	Validation Loss: 87.00646281692217	Time: 0:00:00.005182
# Epoch: [2/100]	Samples: [986/49300]	Train Loss: 87.94572649911258	Time: 0:00:00.024559
# Epoch: [2/100]	Samples: [106/10600]	Validation Loss: 87.23035819575472	Time: 0:00:00.003170
# Epoch: [3/100]	Samples: [1479/49300]	Train Loss: 87.79614505419624	Time: 0:00:00.024450
# Epoch: [3/100]	Samples: [106/10600]	Validation Loss: 87.84505822523585	Time: 0:00:00.002835
# Epoch: [4/100]	Samples: [1972/49300]	Train Loss: 87.4179137812183	Time: 0:00:00.025200
# Epoch: [4/100]	Samples: [106/10600]	Validation Loss: 88.13738668189859	Time: 0:00:00.003140
# Epoch: [5/100]	Samples: [2465/49300]	Train Loss: 86.63504987797921	Time: 0:00:00.022810
# Epoch: [5/100]	Samples: [106/10600]	Validation Loss: 88.50541715801887	Time: 0:00:00.003332
# Epoch: [6/100]	Samples: [2958/49300]	Train Loss: 86.08440629754057	Time: 0:00:00.025166
# Epoch: [6/100]	Samples: [106/10600]	Validation Loss: 88.02016924012382	Time: 0:00:00.002841
# Early stopping

# %%
# Train ProdLDA
model_plda = ProdLDA(num_topics=n_topics)
output_plda = model_plda.train_model(dataset)
# Out:
# Epoch: [1/100]	Samples: [493/49300]	Train Loss: 91.1486405378423	Time: 0:00:00.030914
# Epoch: [1/100]	Samples: [106/10600]	Validation Loss: 86.66553655660377	Time: 0:00:00.003025
# Epoch: [2/100]	Samples: [986/49300]	Train Loss: 90.75813240840517	Time: 0:00:00.028421
# Epoch: [2/100]	Samples: [106/10600]	Validation Loss: 86.64351322965801	Time: 0:00:00.002967
# Epoch: [3/100]	Samples: [1479/49300]	Train Loss: 90.36330006814148	Time: 0:00:00.026040
# Epoch: [3/100]	Samples: [106/10600]	Validation Loss: 87.24422354068396	Time: 0:00:00.003202
# Epoch: [4/100]	Samples: [1972/49300]	Train Loss: 90.19885278666962	Time: 0:00:00.026368
# Epoch: [4/100]	Samples: [106/10600]	Validation Loss: 88.17031572449882	Time: 0:00:00.003013
# Epoch: [5/100]	Samples: [2465/49300]	Train Loss: 89.75755597901876	Time: 0:00:00.024355
# Epoch: [5/100]	Samples: [106/10600]	Validation Loss: 88.51317898732312	Time: 0:00:00.004505
# Epoch: [6/100]	Samples: [2958/49300]	Train Loss: 89.47926042723124	Time: 0:00:00.026235
# Epoch: [6/100]	Samples: [106/10600]	Validation Loss: 88.17877082104953	Time: 0:00:00.003345
# Epoch: [7/100]	Samples: [3451/49300]	Train Loss: 88.74546581833164	Time: 0:00:00.025813
# Epoch: [7/100]	Samples: [106/10600]	Validation Loss: 88.05537616081958	Time: 0:00:00.003701
# Early stopping

# %% [markdown]
# # Evaluation

# %%
# Initialize metrics
topic_diversity = TopicDiversity(topk=10)
topic_coherence = Coherence(texts=dataset.get_corpus(), topk=10, measure='c_npmi')

# %% [markdown]
# ## a) CTM

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_ctm)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_ctm)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.95
# Coherence: -0.4674376223138097

# %% [markdown]
# ## b) ETM

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_etm)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_etm)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.11
# Coherence: 0.034933569236636854

# %% [markdown]
# ## c) HDP

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_hdp)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_hdp)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.7193333333333334
# Coherence: -0.5293217568955078

# %% [markdown]
# ## d) LDA

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_lda)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_lda)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.34
# Coherence: -0.020420641453687476

# %% [markdown]
# ## e) LSI

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_lsi)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_lsi)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.41
# Coherence: -0.016031312082793854

# %% [markdown]
# ## f) NMF

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_nmf)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_nmf)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.55
# Coherence: -0.10330428513513337

# %% [markdown]
# ## g) NeuralLDA

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_nlda)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_nlda)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.97
# Coherence: -0.4326106639786036

# %% [markdown]
# ## h) ProdLDA

# %%
# Retrieve metrics score
topic_diversity_score = topic_diversity.score(output_plda)
print("Topic diversity: " + str(topic_diversity_score))

topic_coherence_score = topic_coherence.score(output_plda)
print("Coherence: " + str(topic_coherence_score))
# Out:
# Topic diversity: 0.92
# Coherence: -0.48635111965918254
